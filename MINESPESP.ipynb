# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8


version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit)

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version
if server_type == 'fabric':
    serverURL = 'https://maven.fabricmc.net/net/fabricmc/fabric-installer/0.11.2/fabric-installer-0.11.2.jar'

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version

jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading



#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)



# Instalar OpenJDK


version = colabconfig["server_version"]

if colabconfig["server_version"] < "1.17":

    # !sudo apt-get purge openjdk* > /dev/null 2>&1

    # !sudo apt-get install openjdk-8-jre-headless &>/dev/null and print("OpenJDK 8 instalado!") or print("Error al intalar OpenJDK 8.")

else:

    # !sudo apt-get purge openjdk* > /dev/null 2>&1

    # !sudo apt-get install openjdk-17-jre-headless &>/dev/null and print("OpenJDK 17 instalado!") or print("Error al intalar OpenJDK 17.")


# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

if java_ver[0] == "17":

    print("Estas usando JAVA 17.")

else:

    print("Estas usando una version desactualizada de java. Puedo que Minecraft 1.17+ no funcione.")



#Lista de posibles archivos .jar


jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar"}

jar_name = jar_list[colabconfig["server_type"]]



# Java arguments.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2ct4URgKlRB8Cu89UOnFl4MvFU2_5oUGQ8vfiscrGLM4KBSTP" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))



print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]

    if colabconfig["server_version"] < "1.17":

        oldpathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/forge-{version}-*.jar")

        if oldpathtoforge: # Checa si la lista no esta vacia

            path = oldpathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java $memory_allocation -jar "{path}" nogui

        else:

            print("No se encontro la version de Forge universal.")

    else:

        pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{version}-/unix_.txt")

        if pathtoforge: # Checa si la lista no esta vacia

            path = pathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java @user_jvm_args.txt "@{path}" "$@"

        else:

            print("No unix_args.txt found.")
else:

    # !java $memory_allocation $server_flags -jar $jar_name nogui



# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      forge.jar	    mohist.jar	       spigot.yml
# banned-players.json  forge.jar.log  ops.json	       user_jvm_args.txt
# bukkit.yml	     help.yml	    patchouli_books    usercache.json
# colabconfig.json     journeymap     permissions.yml    usernamecache.json
# commands.yml	     libraries	    plugins	       whitelist.json
# config		     logs	    run.bat	       world
# defaultconfigs	     mods	    run.sh
# eula.txt	     mohist-config  server.properties
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `sudo apt-get install openjdk-17-jre-headless &>/dev/null and print("OpenJDK 17 instalado!") or print("Error al intalar OpenJDK 17.")'
# Estas usando una version desactualizada de java. Puedo que Minecraft 1.17+ no funcione.
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 0.tcp.ngrok.io:12732
# Iniciando servidor...
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
#
# Thanks for using Mohist - 1.20.1-580, Java(21.0.2) 65.0 PID: 111897
#
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is 1.20.1-587 but you have 1.20.1-580. The latest version has been built on 2024-02-29 07:46:30. You should update to fix recent bugs!
# Checking libraries, please wait...
# All libraries are nice :)!
# Searching incompatible mods...
# [02:50:57 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.20, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412, nogui]
# [02:50:57 INFO]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [02:50:57 INFO]: ImmediateWindowProvider not loading because launch target is forgeserver
# [02:50:57 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%23111!/ Service=ModLauncher Env=SERVER
# [02:50:58 INFO]: Found 5 dependencies adding them to mods collection
# [02:51:01 INFO]: Compatibility level set to JAVA_17
# [02:51:01 INFO]: Successfully loaded Mixin Connector [org.tlauncher.MixinConnector]
# [02:51:01 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [02:51:01 WARN]: Reference map 'cristellib-forge-refmap.json' for cristellib.mixins.json could not be read. If this is a development environment you can ignore this message
# [02:51:03 WARN]: Error loading class: noobanidus/mods/lootr/config/ConfigManager (java.lang.ClassNotFoundException: noobanidus.mods.lootr.config.ConfigManager)
# [02:51:03 ERROR]: Attempted to load class net/minecraft/client/player/AbstractClientPlayer for invalid dist DEDICATED_SERVER
# [02:51:03 WARN]: Error loading class: net/minecraft/client/player/AbstractClientPlayer (java.lang.RuntimeException: Attempted to load class net/minecraft/client/player/AbstractClientPlayer for invalid dist DEDICATED_SERVER)
# [02:51:03 WARN]: @Mixin target net.minecraft.client.player.AbstractClientPlayer was not found tlskincape-mixins.json:MixinAbstractPlayer
# [02:51:03 ERROR]: Attempted to load class net/minecraft/client/gui/screens/TitleScreen for invalid dist DEDICATED_SERVER
# [02:51:03 WARN]: Error loading class: net/minecraft/client/gui/screens/TitleScreen (java.lang.RuntimeException: Attempted to load class net/minecraft/client/gui/screens/TitleScreen for invalid dist DEDICATED_SERVER)
# [02:51:03 WARN]: @Mixin target net.minecraft.client.gui.screens.TitleScreen was not found tlskincape-mixins.json:MixinMainMenu
# [02:51:03 WARN]: Error loading class: net/minecraft/client/model/PlayerModel (java.lang.ClassNotFoundException: net.minecraft.client.model.PlayerModel)
# [02:51:03 WARN]: @Mixin target net.minecraft.client.model.PlayerModel was not found tlskincape-mixins.json:MixinPlayerModel
# [02:51:03 INFO]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.3.2).
# [02:51:11 INFO]: Registering POI for ResourceKey[minecraft:block / workers:miner_block]
# [02:51:11 INFO]: Registering POI for ResourceKey[minecraft:block / workers:lumberjack_block]
# [02:51:11 INFO]: Registering POI for ResourceKey[minecraft:block / workers:farmer_block]
# [02:51:11 INFO]: Registering POI for ResourceKey[minecraft:block / workers:merchant_block]
# [02:51:11 INFO]: Registering POI for ResourceKey[minecraft:block / workers:shepherd_block]
# [02:51:11 INFO]: Registering POI for ResourceKey[minecraft:block / workers:fisherman_block]
# [02:51:11 INFO]: Registering POI for ResourceKey[minecraft:block / workers:cattle_farmer_block]
# [02:51:11 INFO]: Registering POI for ResourceKey[minecraft:block / workers:chicken_farmer_block]
# [02:51:11 INFO]: Registering POI for ResourceKey[minecraft:block / workers:swineherd_block]
# [02:51:11 INFO]: Registering profession for miner with POI net.minecraftforge.registries.RegistryObject@84ce06a
# [02:51:11 INFO]: Registering profession for lumberjack with POI net.minecraftforge.registries.RegistryObject@2324e55
# [02:51:11 INFO]: Registering profession for farmer with POI net.minecraftforge.registries.RegistryObject@b5b6294e
# [02:51:11 INFO]: Registering profession for merchant with POI net.minecraftforge.registries.RegistryObject@e3fd43b3
# [02:51:11 INFO]: Registering profession for shepherd with POI net.minecraftforge.registries.RegistryObject@dc7f439a
# [02:51:11 INFO]: Registering profession for fisherman with POI net.minecraftforge.registries.RegistryObject@2b647820
# [02:51:11 INFO]: Registering profession for cattle_farmer with POI net.minecraftforge.registries.RegistryObject@2fbf1d36
# [02:51:11 INFO]: Registering profession for chicken_farmer with POI net.minecraftforge.registries.RegistryObject@8de71318
# [02:51:11 INFO]: Registering profession for swineherd with POI net.minecraftforge.registries.RegistryObject@5a68aad6
# [02:51:11 INFO]: Registering C2S receiver with id architectury:sync_ids
# [02:51:11 INFO]: Registering C2S receiver with id artifacts:networking_channel/42a7ad70b1cc371599a0eff744096b8a
# [02:51:11 INFO]: Registering C2S receiver with id artifacts:networking_channel/74a5e841822a3a87854ae896a33430d6
# [02:51:14 INFO]: Constructing module Villagers Follow Emeralds...
# [02:51:14 INFO]: Constructing module Wooden Posts...
# [02:51:14 INFO]: Constructing module Wool Shuts Up Minecarts...
# [02:51:14 INFO]: Constructing module Wraith...
# [02:51:14 INFO]: Constructing module Zombie Villagers On Normal...
# [02:51:14 INFO]: Constructing module More Stone Variants...
# [02:51:14 INFO]: Constructed 160 modules.
# [02:51:14 INFO]: Dispatching ZRegister to 3 listeners
# [02:51:14 INFO]: Dispatching ZRegister$Post to 1 listener
# [02:51:14 INFO]: Dispatching ZRegister to 96 listeners
# [02:51:18 INFO]: Dispatching ZRegister$Post to 6 listeners
# [02:51:21 INFO]: Dispatching ForgeZEntityAttributeCreation (as ZEntityAttributeCreation) to 7 listeners
# [02:51:22 INFO]: Dispatching ZConfigChanged to 2 listeners
# [02:51:22 INFO]: 'zeta' is enabling Zeta's piston structure resolver.
# [02:51:22 INFO]: Dispatching ZConfigChanged to 45 listeners
# [02:51:22 INFO]: Dispatching ZConfigChanged to 45 listeners
# [02:51:22 INFO]: Dispatching ZConfigChanged to 45 listeners
# [02:51:22 INFO]: Messages registered
# [02:51:22 INFO]: Dispatching ForgeZCommonSetup (as ZCommonSetup) to 2 listeners
# [02:51:22 INFO]: Dispatching ForgeZCommonSetup (as ZCommonSetup) to 40 listeners
# [02:51:22 INFO]: Initializing Packet Registries
# [02:51:22 INFO]: Dispatching ZConfigChanged to 45 listeners
# [02:51:22 INFO]: Dispatching ZConfigChanged to 2 listeners
# [02:51:22 INFO]: Dispatching ForgeZLoadComplete (as ZLoadComplete) to 1 listener
# [02:51:22 INFO]: Dispatching ForgeZLoadComplete (as ZLoadComplete) to 6 listeners
# [02:51:22 INFO]: Start loading plugin at snownee.jade.addon.vanilla.VanillaPlugin
# [02:51:22 INFO]: Start loading plugin at snownee.jade.addon.universal.UniversalPlugin
# [02:51:22 INFO]: Start loading plugin at snownee.jade.addon.core.CorePlugin
# [02:51:22 INFO]: Start loading plugin at net.blay09.mods.waystones.compat.JadeIntegration
# [02:51:22 INFO]: Start loading plugin at net.geforcemods.securitycraft.compat.waila.JadeDataProvider
# [02:51:22 INFO]: Start loading plugin at twilightforest.compat.jade.JadeCompat
# [02:51:29 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [02:51:29 WARN]: Registry minecraft:block: Object did not get ID it asked for. Name: securitycraft:alarm Expected: 1793 Got: 3033
# [02:51:29 WARN]: Registry minecraft:block: Object did not get ID it asked for. Name: securitycraft:block_change_detector Expected: 1794 Got: 3034
# [02:51:29 WARN]: Registry minecraft:block: Object did not get ID it asked for. Name: securitycraft:block_pocket_manager Expected: 1795 Got: 3035
# [02:51:29 WARN]: Registry minecraft:block: Object did not get ID it asked for. Name: securitycraft:block_pocket_wall Expected: 1796 Got: 3036
# [02:51:29 WARN]: Registry minecraft:block: Object did not get ID it asked for. Name: securitycraft:bouncing_betty Expected: 1797 Got: 3037
# [02:51:29 WARN]: Registry minecraft:block: Object did not get ID it asked for. Name: securitycraft:cage_trap Expected: 1798 Got: 3038
# [02:51:29 WARN]: Registry minecraft:block: Object did not get ID it asked for. Name: securitycraft:claymore Expected: 1799 Got: 3039
# [02:51:29 WARN]: Registry minecraft:block: Object did not get ID it asked for. Name: securitycraft:display_case Expected: 1800 Got: 3040
# [02:51:29 WARN]: Registry minecraft:block: Object did not get ID it asked for. Name: securitycraft:floor_trap Expected: 1801 Got: 3041
# [02:51:29 WARN]: Registry minecraft:block: Object did not get ID it asked for. Name: securitycraft:keypad_frame Expected: 1802 Got: 3042
# [02:51:29 WARN]: Registry minecraft:block: Object did not get ID it asked for. Name: securitycraft:glow_display_case Expected: 1803 Got: 3043
# [02:51:29 WARN]: Registry minecraft:block: Object did not get ID it asked for. Name: securitycraft:ims Expected: 1804 Got: 3044
# [02:51:29 WARN]: Registry minecraft:block: Object did not get ID it asked for. Name: securitycraft:inventory_scanner Expected: 1805 Got: 3045
# [02:51:29 WARN]: Registry minecraft:block: Object did not get ID it asked for. Name: securitycraft:inventory_scanner_field Expected: 1806 Got: 3046
# [02:51:29 WARN]: Registry minecraft:block: Object did not get ID it asked for. Name: securitycraft:electrified_iron_fence Expected: 1807 Got: 3047
# [02:51:29 WARN]: Registry minecraft:block: Object did not get ID it asked for. Name: securitycraft
[modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.BootstrapLaunchConsumer.accept(BootstrapLaunchConsumer.java:26) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.BootstrapLaunchConsumer.accept(BootstrapLaunchConsumer.java:23) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.bootstraplauncher.BootstrapLauncher.main(BootstrapLauncher.java:141) [bootstraplauncher-1.1.2.jar:?]
# 	at com.mohistmc.MohistMCStart.main(MohistMCStart.java:106) [mohist.jar:1.20.1-580]
# [02:51:38 INFO]: Skipping loading recipe twilightforest:jeed/fire_resistance as it's serializer returned null
# [02:51:38 INFO]: Loaded 21 recipes
# [02:51:38 INFO]: [Automatic Recipe Unlock] Removed 3184 recipe advancements
# [02:51:38 INFO]: Loaded 430 advancements
# [02:51:38 INFO]: Loaded 11 curio slots
# [02:51:38 INFO]: Loaded 1 curio entities
# [02:51:38 INFO]: Modified advancement minecraft:husbandry/wax_on with 2 patches
# [02:51:38 INFO]: Modified advancement minecraft:adventure/kill_a_mob with 3 patches
# [02:51:38 INFO]: Modified advancement minecraft:husbandry/bred_all_animals with 3 patches
# [02:51:38 INFO]: Modified advancement minecraft:adventure/kill_all_mobs with 3 patches
# [02:51:38 INFO]: Modified advancement minecraft:husbandry/balanced_diet with 2 patches
# [02:51:38 INFO]: Modified advancement minecraft:nether/all_effects with 1 patches
# [02:51:38 INFO]: Modified advancement minecraft:husbandry/wax_off with 2 patches
# [02:51:38 INFO]: Modified advancement minecraft:adventure/adventuring_time with 1 patches
# [02:51:38 INFO]: Modified advancement minecraft:nether/all_potions with 1 patches
# [02:51:38 INFO]: Loaded 9 Stalactite configs!
# [02:51:43 INFO]: Dispatching ZTagsUpdated to 1 listener
# [02:51:43 INFO]: Starting minecraft server version 1.20.1
# [02:51:43 INFO]: Loading properties
# [02:51:43 INFO]: Default game type: SURVIVAL
# [02:51:43 INFO]: Generating keypair
# [02:51:43 INFO]: Starting Minecraft server on *:25565
# [02:51:44 INFO]: Using epoll channel type
# [02:51:44 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [02:51:44 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [02:51:44 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [02:51:44 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [02:51:44 INFO]: This server is running Mohist version 1.20.1-580 (MC: 1.20.1) (Implementing API version 1.20.1-R0.1-SNAPSHOT, Forge version 47.2.20, NeoForge version 47.1.79)
# [02:51:45 INFO]: Debug logging is enabled
# [02:51:45 INFO]: Server Ping Player Sample Count: 20
# [02:51:45 INFO]: Using 4 threads for Netty based IO
# [02:51:45 INFO]: Hello Plugins!
# [02:51:47 INFO]: [Essentials] Loading Essentials v2.20.1
# [02:51:47 INFO]: Loading JourneyMap Forge Configs
# [02:51:47 WARN]: Configuration file ./world/serverconfig/securitycraft-server.toml is not correct. Correcting
# [02:51:47 INFO]: Loading JourneyMap Forge Configs
# [02:51:47 WARN]: Incorrect key codebreaker_chance was corrected from null to its default, 0.33.
# [02:51:47 WARN]: Incorrect key allowAdminTool was corrected from null to its default, true.
# [02:51:47 WARN]: Incorrect key shouldSpawnFire was corrected from null to its default, true.
# [02:51:47 WARN]: Incorrect key ableToBreakMines was corrected from null to its default, true.
# [02:51:47 WARN]: Incorrect key smallerMineExplosion was corrected from null to its default, false.
# [02:51:47 WARN]: Incorrect key mineExplodesWhenInCreative was corrected from null to its default, true.
# [02:51:47 WARN]: Incorrect key mineExplosionsBreakBlocks was corrected from null to its default, true.
# [02:51:47 WARN]: Incorrect key laserBlockRange was corrected from null to its default, 5.
# [02:51:47 WARN]: Incorrect key inventoryScannerRange was corrected from null to its default, 2.
# [02:51:47 WARN]: Incorrect key maxAlarmRange was corrected from null to its default, 100.
# [02:51:47 WARN]: Incorrect key allowBlockClaim was corrected from null to its default, false.
# [02:51:47 WARN]: Incorrect key respect_invisibility was corrected from null to its default, false.
# [02:51:47 WARN]: Incorrect key reinforced_block_tint was corrected from null to its default, true.
# [02:51:47 WARN]: Incorrect key force_reinforced_block_tint was corrected from null to its default, false.
# [02:51:47 WARN]: Incorrect key retinalScannerFace was corrected from null to its default, true.
# [02:51:47 WARN]: Incorrect key enable_team_ownership was corrected from null to its default, false.
# [02:51:47 WARN]: Incorrect key disable_thanks_message was corrected from null to its default, false.
# [02:51:47 WARN]: Incorrect key trick_scanners_with_player_heads was corrected from null to its default, false.
# [02:51:47 WARN]: Incorrect key taser_damage was corrected from null to its default, 1.0.
# [02:51:47 WARN]: Incorrect key powered_taser_damage was corrected from null to its default, 2.0.
# [02:51:47 WARN]: Incorrect key taser_effects was corrected from null to its default, [minecraft:weakness|200|2, minecraft:nausea|200|2, minecraft:slowness|200|2].
# [02:51:47 WARN]: Incorrect key powered_taser_effects was corrected from null to its default, [minecraft:weakness|400|5, minecraft:nausea|400|5, minecraft:slowness|400|5].
# [02:51:47 WARN]: Incorrect key laser_damage was corrected from null to its default, 10.0.
# [02:51:47 WARN]: Incorrect key incorrectPasscodeDamage was corrected from null to its default, 4.
# [02:51:47 WARN]: Incorrect key sentry_attackable_entities_allowlist was corrected from null to its default, [].
# [02:51:47 WARN]: Incorrect key sentry_attackable_entities_denylist was corrected from null to its default, [].
# [02:51:47 INFO]: Preparing level "world"
# [02:51:52 INFO]: Preparing start region for dimension minecraft:overworld
# [02:51:54 INFO]: Preparing spawn area: 0%
# [02:51:54 INFO]: Preparing spawn area: 0%
# [02:51:54 INFO]: Preparing spawn area: 0%
# [02:51:54 INFO]: Preparing spawn area: 0%
# [02:51:54 INFO]: Preparing spawn area: 0%
# [02:51:54 INFO]: Preparing spawn area: 0%
# [02:51:55 INFO]: Preparing spawn area: 0%
# [02:51:55 INFO]: Preparing spawn area: 0%
# [02:51:56 INFO]: Preparing spawn area: 0%
# [02:51:56 INFO]: Preparing spawn area: 4%
# [02:51:57 INFO]: Preparing spawn area: 4%
# [02:51:57 INFO]: Preparing spawn area: 4%
# [02:51:58 INFO]: Preparing spawn area: 95%
# [02:51:58 INFO]: Time elapsed: 6208 ms
# [02:51:58 INFO]: Preparing start region for dimension minecraft:the_nether
# [02:51:59 INFO]: Preparing spawn area: 0%
# [02:51:59 INFO]: Preparing spawn area: 0%
# [02:51:59 INFO]: Preparing spawn area: 0%
# [02:51:59 INFO]: Preparing spawn area: 0%
# [02:52:00 INFO]: Preparing spawn area: 5%
# [02:52:00 INFO]: Preparing spawn area: 90%
# [02:52:00 INFO]: Time elapsed: 2556 ms
# [02:52:00 INFO]: Preparing start region for dimension minecraft:the_end
# [02:52:01 INFO]: Preparing spawn area: 0%
# [02:52:01 INFO]: Preparing spawn area: 0%
# [02:52:01 INFO]: Preparing spawn area: 4%
# [02:52:02 INFO]: Preparing spawn area: 82%
# [02:52:02 INFO]: Time elapsed: 1553 ms
# [02:52:02 INFO]: Preparing start region for dimension twilightforest:twilight_forest
# [02:52:02 INFO]: Preparing spawn area: 0%
# [02:52:02 INFO]: Preparing spawn area: 0%
# [02:52:03 INFO]: Preparing spawn area: 0%
# [02:52:03 INFO]: Preparing spawn area: 4%
# [02:52:04 INFO]: Preparing spawn area: 19%
# [02:52:04 INFO]: Time elapsed: 2393 ms
# [02:52:04 INFO]: [Essentials] Enabling Essentials v2.20.1
# [02:52:05 INFO]: You are running a server with limited API functionality. EssentialsX will still work, but certain features may be disabled.
# [02:52:06 INFO]: Attempting to convert old kits in config.yml to new kits.yml
# [02:52:06 INFO]: No kits found to migrate.
# [02:52:06 INFO]: Loaded 39094 items from items.json.
# [02:52:06 INFO]: Using locale en
# [02:52:06 INFO]: ServerListPingEvent: Spigot iterator API
# [02:52:06 INFO]: Starting Metrics. Opt-out using the global bStats config.
# [02:52:06 INFO]: Using superperms-based permissions.
# [02:52:06 INFO]: [Mohist] Enabling Mohist v1.20.1
# [02:52:06 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [02:52:06 INFO]: Done (19.675s)! For help, type "help"
# [02:52:06 INFO]: Successfully initialized permission handler forge:default_handler
# [02:52:06 INFO]: Forwarding forge permission[forge:default_handler] to bukkit[mohist:permission]
# [02:52:06 INFO]: Sending reload packet to clients
# [02:52:06 INFO]: Fetching version information...
# [02:52:30 ERROR]: Channels [securitycraft:securitycraft] rejected their client side version number
# [02:52:30 ERROR]: Terminating connection with client, mismatched mod list
# [02:52:30 INFO]: com.mojang.authlib.GameProfile@79fc83ad[id=373f3fd3-8e5c-3816-9a9f-0fd94c021e5a,name=Usernoob80,properties={},legacy=false] (/127.0.0.1:37258) lost connection: Connection closed - mismatched mod channel list
# [02:53:41 INFO]: Usernoob80 joined the game
# [02:53:41 INFO]: Syncing config to Usernoob80 (373f3fd3-8e5c-3816-9a9f-0fd94c021e5a)
# [02:53:42 INFO]: Usernoob80[/127.0.0.1:49574] logged in with entity id 376 at ([world]179.39823428389303, 79.0, 402.0049408402888)
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [03:03:08 INFO]: Usernoob80 issued server command: /gamemode survival
# [03:03:21 INFO]: Usernoob80 issued server command: /gamemode creative
# [03:03:28 INFO]: Usernoob80 issued server command: /gamemode survival
# [03:03:42 INFO]: Usernoob80 issued server command: /gamemode creative
# [03:07:00 INFO]: Usernoob80 issued server command: /gamemode survival
# [03:07:10 INFO]: Usernoob80 issued server command: /gamemode creative
# [03:08:23 INFO]: Usernoob80 issued server command: /gamemode survival
# [03:08:46 INFO]: Usernoob80 issued server command: /essentials:afk
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [03:21:09 INFO]: Usernoob80 issued server command: /gamemode creative
# [03:21:35 INFO]: Usernoob80 issued server command: /essentials:afk
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
